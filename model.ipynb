# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

from rdkit import Chem
from rdkit.Chem import Descriptors

# %%
df = pd.read_csv('df3.csv')

# %%
df
# Out:
#       Isolation source                    antibiotics Resistance phenotype  \
# 0                Groin                       amikacin          susceptible
# 1                wound                       amikacin          susceptible
# 2                blood                       amikacin          susceptible
# 3               sputum                       amikacin          susceptible
# 4                Urine                       amikacin          susceptible
# ...                ...                            ...                  ...
# 14904            wound                     tobramycin          susceptible
# 14905            wound                     tobramycin          susceptible
# 14906            wound                     tobramycin          susceptible
# 14907            wound  trimethoprim-sulfamethoxazole            resistant
# 14908            wound  trimethoprim-sulfamethoxazole            resistant
#
#        MIC (mg/L)  MolecularWeight  \
# ...

# %%
Y = df['Resistance phenotype'].dropna()

# %%
x = df.drop(columns = 'Resistance phenotype')

# %%
x
# Out:
#        Isolation source  antibiotics  MIC (mg/L)  MolecularWeight  \
# 0                     3            0         4.0            585.6
# 1                    35            0         2.0            585.6
# 2                    16            0         2.0            585.6
# 3                    32            0         2.0            585.6
# 4                    10            0         2.0            585.6
# ...                 ...          ...         ...              ...
# 14904                35           47         4.0            467.5
# 14905                35           47         2.0            467.5
# 14906                35           47         1.0            467.5
# 14907                35           49         2.0            543.6
# 14908                35           49        16.0            543.6
#
#                                          CanonicalSMILES
# 0      C1C(C(C(C(C1NC(=O)C(CCN)O)OC2C(C(C(C(O2)CO)O)N...
# 1      C1C(C(C(C(C1NC(=O)C(CCN)O)OC2C(C(C(C(O2)CO)O)N...
# ...

# %%
y = df['Resistance phenotype']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 y.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 print(Y.count('intermediate'))
#
# TypeError: count() takes 1 positional argument but 2 were given

# %%
y.dropna(subset=['Resistance phenotype'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 y.dropna(subset=['Resistance phenotype'], inplace=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dropna'

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
#label encoding antibiotics
if 'antibiotics' in df.columns:  
    x['antibiotics'] = label_encoder.fit_transform(x['antibiotics'])

# %%
if 'Isolation source' in df.columns:
    x['Isolation source'] = label_encoder.fit_transform(x['Isolation source'])

# %%
x
# Out:
#        Isolation source  antibiotics  MIC (mg/L)  MolecularWeight  \
# 0                     3            0         4.0            585.6
# 1                    35            0         2.0            585.6
# 2                    16            0         2.0            585.6
# 3                    32            0         2.0            585.6
# 4                    10            0         2.0            585.6
# ...                 ...          ...         ...              ...
# 14904                35           47         4.0            467.5
# 14905                35           47         2.0            467.5
# 14906                35           47         1.0            467.5
# 14907                35           49         2.0            543.6
# 14908                35           49        16.0            543.6
#
#                                          CanonicalSMILES
# 0      C1C(C(C(C(C1NC(=O)C(CCN)O)OC2C(C(C(C(O2)CO)O)N...
# 1      C1C(C(C(C(C1NC(=O)C(CCN)O)OC2C(C(C(C(O2)CO)O)N...
# ...

# %%
def smiles_to_features(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        # Calculate various descriptors
        return [
            Descriptors.NumHDonors(mol),          
            Descriptors.NumHAcceptors(mol),      
            Descriptors.NumRotatableBonds(mol),  
            Descriptors.TPSA(mol),                              
        ]
    else:
        return [0]*4

# %%
features = df['CanonicalSMILES'].apply(smiles_to_features)

# %%
features
# Out:
# 0                   [13, 17, 10, 331.94]
# 1                   [13, 17, 10, 331.94]
# 2                   [13, 17, 10, 331.94]
# 3                   [13, 17, 10, 331.94]
# 4                   [13, 17, 10, 331.94]
#                       ...
# 14904    [10, 14, 6, 268.16999999999996]
# 14905    [10, 14, 6, 268.16999999999996]
# 14906    [10, 14, 6, 268.16999999999996]
# 14907     [4, 12, 8, 203.73000000000002]
# 14908     [4, 12, 8, 203.73000000000002]
# Name: CanonicalSMILES, Length: 14909, dtype: object

# %%
features_df = pd.DataFrame(features.tolist(), columns=['NumHDonors', 'NumHAcceptors', 
    'NumRotatableBonds', 'TPSA'])

# %%
features_df
# Out:
#        NumHDonors  NumHAcceptors  NumRotatableBonds    TPSA
# 0              13             17                 10  331.94
# 1              13             17                 10  331.94
# 2              13             17                 10  331.94
# 3              13             17                 10  331.94
# 4              13             17                 10  331.94
# ...           ...            ...                ...     ...
# 14904          10             14                  6  268.17
# 14905          10             14                  6  268.17
# 14906          10             14                  6  268.17
# 14907           4             12                  8  203.73
# 14908           4             12                  8  203.73
#
# [14909 rows x 4 columns]

# %%
X = pd.concat([features_df, x], axis=1)

# %%
X = X.drop(columns = 'CanonicalSMILES')

# %%
X
# Out:
#        NumHDonors  NumHAcceptors  NumRotatableBonds    TPSA  Isolation source  \
# 0              13             17                 10  331.94                 3
# 1              13             17                 10  331.94                35
# 2              13             17                 10  331.94                16
# 3              13             17                 10  331.94                32
# 4              13             17                 10  331.94                10
# ...           ...            ...                ...     ...               ...
# 14904          10             14                  6  268.17                35
# 14905          10             14                  6  268.17                35
# 14906          10             14                  6  268.17                35
# 14907           4             12                  8  203.73                35
# 14908           4             12                  8  203.73                35
#
# ...

# %%
y
# Out:
# array([2, 2, 2, ..., 2, 1, 1])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
print(classification_report(y_test, y_pred, target_names=['susceptible', 'resistant','unknown']))
# Out:
# Accuracy: 97.45%
#               precision    recall  f1-score   support
#
#  susceptible       0.74      0.72      0.73       113
#    resistant       0.98      0.97      0.98       928
#      unknown       0.98      0.99      0.99      1941
#
#     accuracy                           0.97      2982
#    macro avg       0.90      0.89      0.90      2982
# weighted avg       0.97      0.97      0.97      2982

# %%
#test
import numpy as np
a = "C1C(C(C(C(C1NC(=O)C(CCN)O)OC2C(C(C(C(O2)CO)O)N)O)O)OC3C(C(C(C(O3)CN)O)O)O)N"
ab = label_encoder.fit_transform(a)
new_features = smiles_to_features(a)
n = label_encoder.fit_transform(new_features)
print(n)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 4
#       2 import numpy as np
#       3 a = "C1C(C(C(C(C1NC(=O)C(CCN)O)OC2C(C(C(C(O2)CO)O)N)O)O)OC3C(C(C(C(O3)CN)O)O)O)N"
# ----> 4 ab = label_encoder.fit_transform(a)
#       5 new_features = smiles_to_features(a)
#       6 n = label_encoder.fit_transform(new_features)
#
# File ~/miniconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:114, in LabelEncoder.fit_transform(self, y)
#     101 def fit_transform(self, y):
#     102     """Fit label encoder and return encoded labels.
#     103
#     104     Parameters
#    (...)
#     112         Encoded labels.
#     113     """
# --> 114     y = column_or_1d(y, warn=True)
#     115     self.classes_, y = _unique(y, return_inverse=True)
#     116     return y
#
# ...

# %%
a = "C1C(C(C(C(C1NC(=O)C(CCN)O)OC2C(C(C(C(O2)CO)O)N)O)O)OC3C(C(C(C(O3)CN)O)O)O)N"
an = []
an.append(a)
ab = label_encoder.fit_transform(an)
# Out:
# [0]

# %%
prediction = model.predict(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 prediction = model.predict(d)
#
# File ~/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:904, in ForestClassifier.predict(self, X)
#     883 def predict(self, X):
#     884     """
#     885     Predict class for X.
#     886
#    (...)
#     902         The predicted classes.
#     903     """
# --> 904     proba = self.predict_proba(X)
#     906     if self.n_outputs_ == 1:
#     907         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:946, in ForestClassifier.predict_proba(self, X)
#     944 check_is_fitted(self)
#     945 # Check data
# --> 946 X = self._validate_X_predict(X)
#     948 # Assign chunk of trees to jobs
# ...
